# %% [markdown]
# # Oracle/HITS model-coupling ablation
#
# Compare combined versus separate oracle models and two-model versus four-model HITS systems. Train on 2024 and backtest on 2025 with separate long and short books.

# %%
# %run ../scripts/run_oracle_hits_model_coupling_ablation.py
