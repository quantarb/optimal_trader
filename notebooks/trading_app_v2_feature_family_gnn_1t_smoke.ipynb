# %% [markdown]
# # Trading App v2: Feature-family GNN with sparse HITS
#
# Train on 2024 and backtest on 2025. Each feature family has its own causal temporal GNN with an auxiliary pairwise-return edge head and a hub/authority node head. The node head is trained on sparse top/bottom HITS tails from independent long and short symbol-year graphs.

# %%
# Set GNN_FAMILIES to one family for a quick smoke test, e.g. price_technicals.
# %run ../scripts/run_feature_family_gnn_smoke.py
