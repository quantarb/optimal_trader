# %% [markdown]
# # Trading App v2: Feature-family GNN smoke test
#
# Train on 2024 and backtest on 2025 for the 1T universe. Each feature family has its own causal temporal GNN with an auxiliary pairwise-return edge head and a hub/authority node head. Only the hub/authority head is used at inference.

# %%
# Set GNN_FAMILIES to one family for a quick smoke test, e.g. price_technicals.
# %run ../scripts/run_feature_family_gnn_smoke.py
