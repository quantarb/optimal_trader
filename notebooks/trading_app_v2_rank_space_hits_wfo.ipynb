# %% [markdown]
# # Trading App v2: Rank-Space HITS DP WFO
#
# This experiment converts daily cross-sectional HITS scores into positive synthetic prices, runs DP independently on each symbol's rank time series, and uses those trades as ML labels. The backtest remains on real prices.

# %%
# %run ../scripts/run_rank_space_hits_wfo.py
