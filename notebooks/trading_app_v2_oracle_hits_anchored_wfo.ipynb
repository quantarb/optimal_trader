# %% [markdown]
# # Oracle versus HITS anchored walk-forward
#
# Train on all data through 2020, backtest one calendar year at a time from 2021 onward, and retrain annually. Oracle uses separate long/short event classifiers. HITS uses separate hub/authority entry/exit regressors for long and short books.

# %%
# %run ../scripts/run_oracle_hits_anchored_wfo.py
