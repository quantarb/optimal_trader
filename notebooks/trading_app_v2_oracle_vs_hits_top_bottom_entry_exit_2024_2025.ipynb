# %% [markdown]
# # Oracle versus top/bottom HITS entry/exit labels
#
# Train on 2024 and backtest on 2025 for 1T, 100B, and 10B. Oracle models train only on buy/sell or short/cover event dates. Each HITS hub/authority regressor trains only on the top and bottom 20% of its own score within each symbol-year; the middle dates are omitted. Long and short strategies are evaluated separately.

# %%
# %run ../scripts/run_oracle_vs_hits_entry_exit_2024_2025.py
